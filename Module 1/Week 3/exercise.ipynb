# %% [markdown]
# ## 1. Write class and build Softmax

# %% [markdown]
# Build `Softmax` and `softmax_stable` layers with the input of a 1D tensor inherited from `torch.nn.Module` layer

# %%
import torch
import torch.nn as nn

class Softmax(nn.Module):
  def __init__(self):
    super(Softmax, self).__init__()

  def forward(self, x):
    exp_x = torch.exp(x)
    return exp_x / sum(exp_x)

class softmax_stable(nn.Module):
  def __init__(self):
    super(softmax_stable, self).__init__()

  def forward(self, x):
    exp_xc = torch.exp(x - torch.max(x))
    return exp_xc / sum(exp_xc)

# %%
data = torch.Tensor([1,2,3])
softmax = Softmax()
output = softmax(data)
print(output)

data = torch.Tensor([1,2,3])
softmax_stable = softmax_stable()
output = softmax_stable(data)
print(output)
# Out:
# tensor([0.0900, 0.2447, 0.6652])
# tensor([0.0900, 0.2447, 0.6652])

# %% [markdown]
# ## 2. Create a Ward class

# %% [markdown]
# A ward includes:
# - name (string)
# - list of people:
#   - Student includes name, year of birth (int) and grade (string)
#   - Teacher includes name, year of birth (int) and subject (string)
#   - Doctor includes name, year of birth (int), specialist (string)

# %% [markdown]
# ### **Task a:** Create Student, Doctor and Teacher classes and use `describe()` method to print in4 of objects

# %%
class Student():
  def __init__(self, name, yob, grade):
    self.name = name
    self.yob = yob
    self.grade = grade

  def describe(self):
    return f'Student - Name: {self.name} - YoB: {self.yob} - Grade: {self.grade}'

class Teacher():
  def __init__(self, name, yob, subject):
    self.name = name
    self.yob = yob
    self.subject = subject

  def describe(self):
    return f'Teacher - Name: {self.name} - YoB: {self.yob} - Subject: {self.subject}'

class Doctor():
  def __init__(self, name, yob, specialist):
    self.name = name
    self.yob = yob
    self.specialist = specialist

  def describe(self):
    return f'Doctor - Name: {self.name} - YoB: {self.yob} - Specialist: {self.specialist}'

# %%
student1 = Student("studentA", 2010, "7")

student1.describe()
# Out:
# 'Student - Name: studentA - YoB: 2010 - Grade: 7'

# %%
teacher1 = Teacher('teacherA', 1969, 'Math')

teacher1.describe()
# Out:
# 'Teacher - Name: teacherA - YoB: 1969 - Subject: Math'

# %%
doctor1 = Doctor('doctorA', 1945, 'Endocrinologists')

doctor1.describe()
# Out:
# 'Doctor - Name: doctorA - YoB: 1945 - Specialist: Endocrinologists'

# %% [markdown]
# ### **Task b:**
# - Build Ward class and write `add_person(person)` method to add a new person
# - Write `describe()` method to print the in4 of all people in the Ward

# %%
class Ward:
  def __init__(self, name):
    self.name = name
    self.people = []

  def add_person(self, person):
    self.people.append(person)

  def describe(self):
      description = f'Ward: {self.name}\n'
      for person in self.people:
        description += person.describe() + '\n'
      return description

# %%
teacher2 = Teacher('teacherB', 1995, 'History')
doctor2 = Doctor('doctorB', 1975, 'Cardiologists')

ward1 = Ward('Ward1')
ward1.add_person(student1)
ward1.add_person(teacher1)
ward1.add_person(teacher2)
ward1.add_person(doctor1)
ward1.add_person(doctor2)

print(ward1.describe())
# Out:
# Ward: Ward1
# Student - Name: studentA - YoB: 2010 - Grade: 7
# Teacher - Name: teacherA - YoB: 1969 - Subject: Math
# Teacher - Name: teacherB - YoB: 1995 - Subject: History
# Doctor - Name: doctorA - YoB: 1945 - Specialist: Endocrinologists
# Doctor - Name: doctorB - YoB: 1975 - Specialist: Cardiologists

# %% [markdown]
# ### **Task c:** Write `count_doctor()` method

# %%
class Ward:
  def __init__(self, name):
    self.name = name
    self.people = []

  def add_person(self, person):
    self.people.append(person)

  def count_doctor(self):
    return sum(1 for person in self.people if isinstance(person, Doctor))

# %%
ward1 = Ward('Ward1')
ward1.add_person(student1)
ward1.add_person(teacher1)
ward1.add_person(teacher2)
ward1.add_person(doctor1)
ward1.add_person(doctor2)

ward1.count_doctor()
# Out:
# 2

# %% [markdown]
# ### Task d: Write `sort_age()` method

# %%
class Ward:
  def __init__(self, name):
    self.name = name
    self.people = []

  def add_person(self, person):
    self.people.append(person)

  def sort_age(self):
    self.people.sort(key=lambda person: person.yob, reverse=True)

  def describe(self):
    description = f'Ward: {self.name} \n'
    for person in self.people:
      description += person.describe() + '\n'
    return description

# %%
ward1 = Ward('Ward1')
ward1.add_person(student1)
ward1.add_person(teacher1)
ward1.add_person(teacher2)
ward1.add_person(doctor1)
ward1.add_person(doctor2)

ward1.sort_age()
print(ward1.describe())
# Out:
# Ward: Ward1
# Student - Name: studentA - YoB: 2010 - Grade: 7
# Teacher - Name: teacherB - YoB: 1995 - Subject: History
# Doctor - Name: doctorB - YoB: 1975 - Specialist: Cardiologists
# Teacher - Name: teacherA - YoB: 1969 - Subject: Math
# Doctor - Name: doctorA - YoB: 1945 - Specialist: Endocrinologists

# %% [markdown]
# ### **Task e**: Write `compute_average()` method to count the avarage of yob of teachers in Ward

# %%
class Ward:
  def __init__(self, name):
    self.name = name
    self.people = []

  def add_person(self, person):
    self.people.append(person)

  def compute_average(self):
    teachers = [person.yob for person in self.people if isinstance(person, Teacher)]
    if not teachers:
      return 0
    return sum(teachers) / len(teachers)

# %%
ward1 = Ward('Ward1')
ward1.add_person(student1)
ward1.add_person(teacher1)
ward1.add_person(teacher2)
ward1.add_person(doctor1)
ward1.add_person(doctor2)

print(f'Average year of birth (teacher) : {ward1.compute_average()}')
# Out:
# Average year of birth (teacher) : 1982.0

# %% [markdown]
# ## Build the Stack class

# %% [markdown]
# - **initialization** method with input "capacity": initialize stack with capacity is the number of elements that stack can have
# - **is_empty()**
# - **is_full()**
# - **pop()**
# - **push(value)**
# - **top()**

# %%
class Stack:
  def __init__(self, capacity):
    self.stack = []
    self.capacity = capacity

  def is_empty(self):
    return len(self.stack) == 0

  def is_full(self):
    return len(self.stack) == self.capacity

  def pop(self):
    if self.is_empty():
      raise IndexError('Pop from an empty stack')
    else:
      return self.stack.pop(-1)

  def push(self, value):
    if self.is_full():
      raise IndexError('Top from a full stack')
    else:
      self.stack.append(value)

  def top(self):
    if self.is_empty():
      raise IndexError('Top from an empty stack')
    return self.stack[-1]

# %%
stack1 = Stack(5)
stack1.is_empty()
# Out:
# True

# %%
stack1.push(1)
stack1.push(2)
stack1.push(3)
stack1.push(4)
stack1.push(5)
stack1.push(6)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-b4df455af379> in <cell line: 6>()
#       4 stack1.push(4)
#       5 stack1.push(5)
# ----> 6 stack1.push(6)
#
# <ipython-input-16-c896a5a3005e> in push(self, value)
#      18   def push(self, value):
#      19     if self.is_full():
# ---> 20       raise IndexError('Top from a full stack')
#      21     else:
#      22       self.stack.append(value)
#
# IndexError: Top from a full stack

# %%
print(stack1.is_full())
print(stack1.top())
# Out:
# True
# 5

# %%
stack1.pop()
stack1.pop()
stack1.pop()
stack1.pop()
stack1.pop()
stack1.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-412eff5a63f0> in <cell line: 6>()
#       4 stack1.pop()
#       5 stack1.pop()
# ----> 6 stack1.pop()
#
# <ipython-input-16-c896a5a3005e> in pop(self)
#      12   def pop(self):
#      13     if self.is_empty():
# ---> 14       raise IndexError('Pop from an empty stack')
#      15     else:
#      16       return self.stack.pop(-1)
#
# IndexError: Pop from an empty stack

# %%
print(stack1.is_empty())
print(stack1.top())
# Out:
# True
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-27aa04cc6e4a> in <cell line: 2>()
#       1 print(stack1.is_empty())
# ----> 2 print(stack1.top())
#
# <ipython-input-16-c896a5a3005e> in top(self)
#      24   def top(self):
#      25     if self.is_empty():
# ---> 26       raise IndexError('Top from an empty stack')
#      27     return self.stack[-1]
#
# IndexError: Top from an empty stack

# %% [markdown]
# ## 4. Build Queue class

# %% [markdown]
# - initialization
# - is_empty
# - is_full
# - enqueue
# - dequeue
# - front

# %%
class Queue():
  def __init__(self, capacity):
    self.capacity = capacity
    self.queue = []

  def is_empty(self):
    return len(self.queue) == 0

  def is_full(self):
    return len(self.queue) == self.capacity

  def dequeue(self):
    if self.is_empty():
      raise IndexError('Dequeue an empty queue')
    else:
      return self.queue.pop(0)

  def enqueue(self, value):
    if self.is_full():
      raise IndexError('Enqueue a full queue')
    else:
      self.queue.append(value)

  def front(self):
    if self.is_empty():
      raise IndexError('Front an empty queue')
    else:
      return self.queue[0]

# %%
queue1 = Queue(5)
queue1.is_empty()
# Out:
# True

# %%
queue1.enqueue(1)
queue1.enqueue(2)
queue1.enqueue(3)
queue1.enqueue(4)
queue1.enqueue(5)
queue1.enqueue(6)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-f69a5cf18498> in <cell line: 6>()
#       4 queue1.enqueue(4)
#       5 queue1.enqueue(5)
# ----> 6 queue1.enqueue(6)
#
# <ipython-input-26-5f36fea03adc> in enqueue(self, value)
#      18   def enqueue(self, value):
#      19     if self.is_full():
# ---> 20       raise IndexError('Enqueue a full queue')
#      21     else:
#      22       self.queue.append(value)
#
# IndexError: Enqueue a full queue

# %%
print(queue1.is_full())
print(queue1.front())
# Out:
# True
# 1

# %%
queue1.dequeue()
queue1.dequeue()
queue1.dequeue()
queue1.dequeue()
queue1.dequeue()
queue1.dequeue()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-037716b66dba> in <cell line: 6>()
#       4 queue1.dequeue()
#       5 queue1.dequeue()
# ----> 6 queue1.dequeue()
#
# <ipython-input-26-5f36fea03adc> in dequeue(self)
#      12   def dequeue(self):
#      13     if self.is_empty():
# ---> 14       raise IndexError('Dequeue an empty queue')
#      15     else:
#      16       return self.queue.pop(0)
#
# IndexError: Dequeue an empty queue

# %%
print(queue1.is_empty())
print(queue1.front())
# Out:
# True
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-31ce651d048c> in <cell line: 2>()
#       1 print(queue1.is_empty())
# ----> 2 print(queue1.front())
#
# <ipython-input-26-5f36fea03adc> in front(self)
#      24   def front(self):
#      25     if self.is_empty():
# ---> 26       raise IndexError('Front an empty queue')
#      27     else:
#      28       return self.queue[0]
#
# IndexError: Front an empty queue
